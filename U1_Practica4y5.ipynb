# %% [markdown]
# <a href="https://colab.research.google.com/github/celii017/Probabilidad-y-estadistica/blob/main/U1_Practica4y5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# UNIDAD 1
# PRACTICA 4
# TABLAS DE FRECUENCIAS

# %%
import random
edades = []
# Hacemos un ciclo para generar 100 numeros aleatorios que representen la edad de las personas
for i in range(100):
 # generamos un numero aleatorio con la funcion randint y lo guardamosen la variable
 # numero_aleatorio
 numero_aleatorio = random.randint( 18,70)
 #Agregamos el numero aleatorio a la lista de valores
 edades.append(numero_aleatorio)
print(edades)
# Out:
# [27, 59, 66, 36, 43, 51, 70, 54, 52, 54, 41, 25, 46, 22, 45, 55, 60, 51, 58, 56, 27, 62, 32, 23, 47, 49, 23, 37, 66, 20, 33, 58, 59, 23, 67, 38, 61, 54, 25, 46, 54, 67, 54, 32, 35, 49, 40, 26, 27, 21, 23, 70, 56, 31, 33, 61, 20, 20, 51, 21, 37, 26, 33, 58, 55, 59, 19, 20, 42, 61, 29, 35, 30, 60, 48, 66, 24, 28, 51, 49, 29, 60, 22, 51, 69, 62, 18, 69, 53, 62, 40, 38, 22, 36, 43, 62, 33, 20, 37, 54]

# %%
import pandas as pd

# %%
# Crear un DataFrame de pandas con los numeros aleatorios
df = pd.DataFrame(edades, columns=['edades'])
df.head()
# Out:
#    edades
# 0      27
# 1      59
# 2      66
# 3      36
# 4      43

# %%
# Calcular la tabla de distribucion de frecuencias
tabla_frecuencias = df['edades'].value_counts().reset_index()
tabla_frecuencias.columns = ['edad', 'Frecuencia']
tabla_frecuencias =  tabla_frecuencias.sort_values(by='edad')

# Imprimir la tabla de distribucionb de frecuencias
print("Tabla de Distribucion de frecuencias:")
tabla_frecuencias
# Out:
# Tabla de Distribucion de frecuencias:
#     edad  Frecuencia
# 32    18           1
# 38    19           1
# 1     20           5
# 16    21           2
# 14    22           3
# 4     23           4
# 33    24           1
# 28    25           2
# 17    26           2
# 6     27           3
# 31    28           1
# 15    29           2
# 35    30           1
# 39    31           1
# 27    32           2
# 3     33           4
# 19    35           2
# 23    36           2
# 9     37           3
# 21    38           2
# 18    40           2
# 42    41           1
# 37    42           1
# 24    43           2
# 36    45           1
# 30    46           2
# 41    47           1
# 34    48           1
# 12    49           3
# 2     51           5
# 40    52           1
# 43    53           1
# 0     54           6
# 20    55           2
# 29    56           2
# 11    58           3
# 10    59           3
# 7     60           3
# 8     61           3
# 5     62           4
# ...

# %%
tabla_frecuencias['Frecuencia_relativa'] = tabla_frecuencias['Frecuencia'] /100
tabla_frecuencias
# Out:
#     edad  Frecuencia  Frecuencia_relativa
# 32    18           1                 0.01
# 38    19           1                 0.01
# 1     20           5                 0.05
# 16    21           2                 0.02
# 14    22           3                 0.03
# 4     23           4                 0.04
# 33    24           1                 0.01
# 28    25           2                 0.02
# 17    26           2                 0.02
# 6     27           3                 0.03
# 31    28           1                 0.01
# 15    29           2                 0.02
# 35    30           1                 0.01
# 39    31           1                 0.01
# 27    32           2                 0.02
# 3     33           4                 0.04
# 19    35           2                 0.02
# 23    36           2                 0.02
# 9     37           3                 0.03
# 21    38           2                 0.02
# 18    40           2                 0.02
# ...

# %%
tabla_frecuencias['Frecuencia modulada'] = tabla_frecuencias['Frecuencia'] /100
tabla_frecuencias
# Out:
#     edad  Frecuencia  Frecuencia_relativa  Frecuencia modulada
# 32    18           1                 0.01                 0.01
# 38    19           1                 0.01                 0.01
# 1     20           5                 0.05                 0.05
# 16    21           2                 0.02                 0.02
# 14    22           3                 0.03                 0.03
# 4     23           4                 0.04                 0.04
# 33    24           1                 0.01                 0.01
# 28    25           2                 0.02                 0.02
# 17    26           2                 0.02                 0.02
# 6     27           3                 0.03                 0.03
# 31    28           1                 0.01                 0.01
# 15    29           2                 0.02                 0.02
# 35    30           1                 0.01                 0.01
# 39    31           1                 0.01                 0.01
# ...

# %%
# Importamos la libreria math de funciones matematicas
import math

# %%
#volvemos a usar la lista de edades
print(edades)
# Out:
# [27, 59, 66, 36, 43, 51, 70, 54, 52, 54, 41, 25, 46, 22, 45, 55, 60, 51, 58, 56, 27, 62, 32, 23, 47, 49, 23, 37, 66, 20, 33, 58, 59, 23, 67, 38, 61, 54, 25, 46, 54, 67, 54, 32, 35, 49, 40, 26, 27, 21, 23, 70, 56, 31, 33, 61, 20, 20, 51, 21, 37, 26, 33, 58, 55, 59, 19, 20, 42, 61, 29, 35, 30, 60, 48, 66, 24, 28, 51, 49, 29, 60, 22, 51, 69, 62, 18, 69, 53, 62, 40, 38, 22, 36, 43, 62, 33, 20, 37, 54]

# %%
# Crear un DataFrame con las edades
df = pd.DataFrame({'edad': edades})
df
# Out:
#     edad
# 0     27
# 1     59
# 2     66
# 3     36
# 4     43
# ..   ...
# 95    62
# 96    33
# 97    20
# 98    37
# 99    54
#
# [100 rows x 1 columns]

# %%
# Calcular el numero de intervalos utilizando la regla de Sturges
n = len(edades)
k = int( 1 + math.log2(n))
print("Valor de n = ", n , " /2nNumero de intervalos =", k)
# Out:
# Valor de n =  100  /2nNumero de intervalos = 7

# %%
#Crear la tabla de frecuencia
tabla_frecuencia= pd.cut( df['edad'], bins=k, include_lowest=True).value_counts().reset_index()
tabla_frecuencia.columns = ['clase', 'Frec']
tabla_frecuencia
# Out:
#               clase  Frec
# 0  (17.947, 25.429]    19
# 1  (47.714, 55.143]    19
# 2  (55.143, 62.571]    18
# 3  (32.857, 40.286]    15
# 4  (25.429, 32.857]    12
# 5    (62.571, 70.0]     9
# 6  (40.286, 47.714]     8

# %%
# Ordenar la tabla de frecuencia por el intervalo
tabla_frecuencia = tabla_frecuencia.sort_values(by='clase')
tabla_frecuencia
# Out:
#               clase  Frec
# 0  (17.947, 25.429]    19
# 4  (25.429, 32.857]    12
# 3  (32.857, 40.286]    15
# 6  (40.286, 47.714]     8
# 1  (47.714, 55.143]    19
# 2  (55.143, 62.571]    18
# 5    (62.571, 70.0]     9

# %%
# Generar columnas siguientes
tabla_frecuencia['Frec Rel'] = tabla_frecuencia['Frec'] / n
tabla_frecuencia['Frec Porc'] = tabla_frecuencia['Frec'] / n *100
tabla_frecuencia['Frec Ac'] = tabla_frecuencia['Frec'].cumsum()
tabla_frecuencia['Frec Rel Ac'] = tabla_frecuencia['Frec Rel'].cumsum()
tabla_frecuencia['Frec Porc Ac'] = tabla_frecuencia['Frec Porc'].cumsum()

# Mostrar la tabla de frecuencia
print(tabla_frecuencia)
# Out:
#               clase  Frec  Frec Rel  Frec Porc  Frec Ac  Frec Rel Ac  \
# 0  (17.947, 25.429]    19      0.19       19.0       19         0.19
# 4  (25.429, 32.857]    12      0.12       12.0       31         0.31
# 3  (32.857, 40.286]    15      0.15       15.0       46         0.46
# 6  (40.286, 47.714]     8      0.08        8.0       54         0.54
# 1  (47.714, 55.143]    19      0.19       19.0       73         0.73
# 2  (55.143, 62.571]    18      0.18       18.0       91         0.91
# 5    (62.571, 70.0]     9      0.09        9.0      100         1.00
#
#    Frec Porc Ac
# 0          19.0
# 4          31.0
# 3          46.0
# 6          54.0
# 1          73.0
# 2          91.0
# 5         100.0

# %%
import matplotlib.pyplot as plt
plt.hist(edades, alpha = 0.5 , bins= 20)
plt.title("Histogramas de edades basado en la funcion de matplotlib con valores estandar")
# Out:
# Text(0.5, 1.0, 'Histogramas de edades basado en la funcion de matplotlib con valores estandar')

# %%
# crear un histograma basado en la tabla de frecuencia
plt.hist(df['edad'], bins=k, alpha = 0.5)
plt.title("Histograma de edades basado en la regla de Sturges")
plt.xlabel('edades')
plt.ylabel('frecuencia')
# Out:
# Text(0, 0.5, 'frecuencia')

# %% [markdown]
# #PRACTICA 5 DIAGRAMA DE CAJAS Y BIGOTES

# %%
import random
edades2 = []
#Hacemos un ciclo para generar 100 numeros aleatorios se representan la edad de las personas
for i in range(100):
 #generaramos un numero aleatorio con la funcion randint y lo guardamos en la variable
 #Numero aleatorio
 numero_aleatorio = random.randint(18,79)
 #agregamos el numero aleatorio en la lista de valores
 edades2.append(numero_aleatorio)
print(edades2)
# Out:
# [21, 49, 51, 53, 43, 38, 47, 64, 22, 44, 25, 71, 20, 23, 77, 64, 54, 25, 56, 37, 36, 69, 42, 34, 71, 67, 66, 71, 22, 33, 64, 65, 79, 66, 27, 71, 68, 69, 73, 75, 27, 42, 67, 50, 25, 27, 77, 51, 60, 76, 35, 60, 26, 19, 32, 56, 58, 58, 69, 67, 25, 32, 41, 36, 23, 44, 22, 31, 47, 64, 64, 44, 53, 31, 21, 26, 27, 21, 67, 48, 62, 42, 42, 41, 40, 18, 35, 22, 20, 68, 51, 59, 79, 73, 72, 65, 64, 54, 21, 74]

# %%
fig, (ax1,ax2) =plt.subplots(nrows=1, ncols=2, figsize=(9,4))
bplot1 = ax1.boxplot(edades,
                    vert=True, # vertical box aligment
                    patch_artist=True) # fill with color
ax1.set_title('edades encuesta 1')

bplot2 =ax2.boxplot(edades2,
                    vert=True, #vertical box aligment
                    patch_artist=True) # fill with color

ax2.set_title('edades encuesta 2')
plt.show()
