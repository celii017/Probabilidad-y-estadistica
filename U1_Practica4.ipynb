# %% [markdown]
# <a href="https://colab.research.google.com/github/celii017/Probabilidad-y-estadistica/blob/main/U1_Practica4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# UNIDAD 1
# PRACTICA 4
# TABLAS DE FRECUENCIAS

# %%
import random
edades = []
# Hacemos un ciclo para generar 100 numeros aleatorios que representen la edad de las personas
for i in range(100):
 # generamos un numero aleatorio con la funcion randint y lo guardamosen la variable
 # numero_aleatorio
 numero_aleatorio = random.randint( 18,70)
 #Agregamos el numero aleatorio a la lista de valores
 edades.append(numero_aleatorio)
print(edades)
# Out:
# [33, 44, 32, 23, 60, 26, 46, 22, 59, 58, 60, 39, 48, 20, 58, 28, 30, 68, 45, 21, 68, 45, 52, 22, 38, 35, 50, 19, 41, 41, 26, 20, 62, 19, 55, 55, 43, 29, 41, 30, 29, 68, 44, 59, 59, 66, 29, 58, 33, 65, 64, 41, 50, 59, 29, 50, 22, 18, 47, 48, 49, 25, 26, 68, 36, 21, 32, 58, 67, 24, 57, 58, 33, 69, 60, 68, 54, 36, 68, 40, 33, 62, 62, 55, 62, 53, 26, 57, 18, 68, 39, 29, 41, 53, 48, 61, 30, 50, 46, 58]

# %%
import pandas as pd

# %%
# Crear un DataFrame de pandas con los numeros aleatorios
df = pd.DataFrame(edades, columns=['edades'])
df.head()
# Out:
#    edades
# 0      33
# 1      44
# 2      32
# 3      23
# 4      60

# %%
# Calcular la tabla de distribucion de frecuencias
tabla_frecuencias = df['edades'].value_counts().reset_index()
tabla_frecuencias.columns = ['edad', 'Frecuencia']
tabla_frecuencias =  tabla_frecuencias.sort_values(by='edad')

# Imprimir la tabla de distribucionb de frecuencias
print("Tabla de Distribucion de frecuencias:")
tabla_frecuencias
# Out:
# Tabla de Distribucion de frecuencias:
#     edad  Frecuencia
# 15    18           2
# 19    19           2
# 23    20           2
# 21    21           2
# 9     22           3
# 31    23           1
# 32    24           1
# 27    25           1
# 8     26           4
# 41    28           1
# 3     29           5
# 12    30           3
# 20    32           2
# 7     33           4
# 26    35           1
# 14    36           2
# 36    38           1
# 24    39           2
# 28    40           1
# 2     41           5
# 40    43           1
# 18    44           2
# 22    45           2
# 25    46           2
# 34    47           1
# 10    48           3
# 35    49           1
# 6     50           4
# 42    52           1
# 17    53           2
# 29    54           1
# 11    55           3
# 16    57           2
# 1     58           6
# 4     59           4
# 13    60           3
# 43    61           1
# 5     62           4
# 37    64           1
# 38    65           1
# 39    66           1
# 33    67           1
# 0     68           7
# 30    69           1

# %%
tabla_frecuencias['Frecuencia_relativa'] = tabla_frecuencias['Frecuencia'] /100
tabla_frecuencias
# Out:
#     edad  Frecuencia  Frecuencia_relativa
# 15    18           2                 0.02
# 19    19           2                 0.02
# 23    20           2                 0.02
# 21    21           2                 0.02
# 9     22           3                 0.03
# 31    23           1                 0.01
# 32    24           1                 0.01
# 27    25           1                 0.01
# 8     26           4                 0.04
# 41    28           1                 0.01
# 3     29           5                 0.05
# 12    30           3                 0.03
# 20    32           2                 0.02
# 7     33           4                 0.04
# 26    35           1                 0.01
# 14    36           2                 0.02
# 36    38           1                 0.01
# 24    39           2                 0.02
# 28    40           1                 0.01
# 2     41           5                 0.05
# 40    43           1                 0.01
# 18    44           2                 0.02
# 22    45           2                 0.02
# 25    46           2                 0.02
# 34    47           1                 0.01
# 10    48           3                 0.03
# 35    49           1                 0.01
# 6     50           4                 0.04
# 42    52           1                 0.01
# 17    53           2                 0.02
# 29    54           1                 0.01
# 11    55           3                 0.03
# 16    57           2                 0.02
# 1     58           6                 0.06
# 4     59           4                 0.04
# 13    60           3                 0.03
# 43    61           1                 0.01
# 5     62           4                 0.04
# 37    64           1                 0.01
# 38    65           1                 0.01
# 39    66           1                 0.01
# 33    67           1                 0.01
# 0     68           7                 0.07
# 30    69           1                 0.01

# %%
tabla_frecuencias['Frecuencia modulada'] = tabla_frecuencias['Frecuencia'] /100
tabla_frecuencias
# Out:
#     edad  Frecuencia  Frecuencia_relativa  Frecuencia modulada
# 15    18           2                 0.02                 0.02
# 19    19           2                 0.02                 0.02
# 23    20           2                 0.02                 0.02
# 21    21           2                 0.02                 0.02
# 9     22           3                 0.03                 0.03
# 31    23           1                 0.01                 0.01
# 32    24           1                 0.01                 0.01
# 27    25           1                 0.01                 0.01
# 8     26           4                 0.04                 0.04
# 41    28           1                 0.01                 0.01
# 3     29           5                 0.05                 0.05
# 12    30           3                 0.03                 0.03
# 20    32           2                 0.02                 0.02
# 7     33           4                 0.04                 0.04
# 26    35           1                 0.01                 0.01
# 14    36           2                 0.02                 0.02
# 36    38           1                 0.01                 0.01
# 24    39           2                 0.02                 0.02
# 28    40           1                 0.01                 0.01
# 2     41           5                 0.05                 0.05
# 40    43           1                 0.01                 0.01
# 18    44           2                 0.02                 0.02
# 22    45           2                 0.02                 0.02
# 25    46           2                 0.02                 0.02
# 34    47           1                 0.01                 0.01
# 10    48           3                 0.03                 0.03
# 35    49           1                 0.01                 0.01
# 6     50           4                 0.04                 0.04
# 42    52           1                 0.01                 0.01
# 17    53           2                 0.02                 0.02
# 29    54           1                 0.01                 0.01
# 11    55           3                 0.03                 0.03
# 16    57           2                 0.02                 0.02
# 1     58           6                 0.06                 0.06
# 4     59           4                 0.04                 0.04
# 13    60           3                 0.03                 0.03
# 43    61           1                 0.01                 0.01
# 5     62           4                 0.04                 0.04
# 37    64           1                 0.01                 0.01
# 38    65           1                 0.01                 0.01
# 39    66           1                 0.01                 0.01
# 33    67           1                 0.01                 0.01
# 0     68           7                 0.07                 0.07
# 30    69           1                 0.01                 0.01

# %%
# Importamos la libreria math de funciones matematicas
import math

# %%
#volvemos a usar la lista de edades
print(edades)
# Out:
# [33, 44, 32, 23, 60, 26, 46, 22, 59, 58, 60, 39, 48, 20, 58, 28, 30, 68, 45, 21, 68, 45, 52, 22, 38, 35, 50, 19, 41, 41, 26, 20, 62, 19, 55, 55, 43, 29, 41, 30, 29, 68, 44, 59, 59, 66, 29, 58, 33, 65, 64, 41, 50, 59, 29, 50, 22, 18, 47, 48, 49, 25, 26, 68, 36, 21, 32, 58, 67, 24, 57, 58, 33, 69, 60, 68, 54, 36, 68, 40, 33, 62, 62, 55, 62, 53, 26, 57, 18, 68, 39, 29, 41, 53, 48, 61, 30, 50, 46, 58]

# %%
# Crear un DataFrame con las edades
df = pd.DataFrame({'edad': edades})
df
# Out:
#     edad
# 0     33
# 1     44
# 2     32
# 3     23
# 4     60
# ..   ...
# 95    61
# 96    30
# 97    50
# 98    46
# 99    58
#
# [100 rows x 1 columns]

# %%
# Calcular el numero de intervalos utilizando la regla de Sturges
n = len(edades)
k = int( 1 + math.log2(n))
print("Valor de n = ", n , " /2nNumero de intervalos =", k)
# Out:
# Valor de n =  100  /2nNumero de intervalos = 7

# %%
#Crear la tabla de frecuencia
tabla_frecuencia= pd.cut( df['edad'], bins=k, include_lowest=True).value_counts().reset_index()
tabla_frecuencia.columns = ['clase', 'Frec']
tabla_frecuencia
# Out:
#               clase  Frec
# 0  (54.429, 61.714]    19
# 1    (61.714, 69.0]    16
# 2  (25.286, 32.571]    15
# 3  (17.948, 25.286]    14
# 4  (39.857, 47.143]    14
# 5  (47.143, 54.429]    12
# 6  (32.571, 39.857]    10

# %%
# Ordenar la tabla de frecuencia por el intervalo
tabla_frecuencia = tabla_frecuencia.sort_values(by='clase')
tabla_frecuencia
# Out:
#               clase  Frec
# 3  (17.948, 25.286]    14
# 2  (25.286, 32.571]    15
# 6  (32.571, 39.857]    10
# 4  (39.857, 47.143]    14
# 5  (47.143, 54.429]    12
# 0  (54.429, 61.714]    19
# 1    (61.714, 69.0]    16

# %%
# Generar columnas siguientes
tabla_frecuencia['Frec Rel'] = tabla_frecuencia['Frec'] / n
tabla_frecuencia['Frec Porc'] = tabla_frecuencia['Frec'] / n *100
tabla_frecuencia['Frec Ac'] = tabla_frecuencia['Frec'].cumsum()
tabla_frecuencia['Frec Rel Ac'] = tabla_frecuencia['Frec Rel'].cumsum()
tabla_frecuencia['Frec Porc Ac'] = tabla_frecuencia['Frec Porc'].cumsum()

# Mostrar la tabla de frecuencia
print(tabla_frecuencia)
# Out:
#               clase  Frec  Frec Rel  Frec Porc  Frec Ac  Frec Rel Ac  \
# 3  (17.948, 25.286]    14      0.14       14.0       14         0.14
# 2  (25.286, 32.571]    15      0.15       15.0       29         0.29
# 6  (32.571, 39.857]    10      0.10       10.0       39         0.39
# 4  (39.857, 47.143]    14      0.14       14.0       53         0.53
# 5  (47.143, 54.429]    12      0.12       12.0       65         0.65
# 0  (54.429, 61.714]    19      0.19       19.0       84         0.84
# 1    (61.714, 69.0]    16      0.16       16.0      100         1.00
#
#    Frec Porc Ac
# 3          14.0
# 2          29.0
# 6          39.0
# 4          53.0
# 5          65.0
# 0          84.0
# 1         100.0
